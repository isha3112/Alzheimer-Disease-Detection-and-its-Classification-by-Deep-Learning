# %% [markdown]
# # Data Augmentation of Normal Patient Data

# %%
import os
import random
import numpy as np
from scipy.io import loadmat, savemat
import mne

# %%
# define the folder path
folder_path = r"D:\Ne\dataset\NORMAL"

# %%
# define the list of data augmentation techniques
augmentations = ['scaling', 'translation', 'flipping']

# %%
# define the output folder path for the augmented data
output_folder_path = r"D:\Ne\dataset\NORMAL"

# %%
# create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# %%
# iterate through each .mat file in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith('.mat'):
        # load the EEG data from the .mat file
        mat_data = loadmat(os.path.join(folder_path, file_name))
        data = mat_data['export']
        ch_names = mat_data.get('ch_names', ['chan'+str(i+1) for i in range(data.shape[0])])
        sfreq = mat_data.get('sfreq', 256)  # default sampling frequency is set to 256 Hz
        info = mne.create_info(ch_names=ch_names, sfreq=sfreq, ch_types='eeg')
        raw = mne.io.RawArray(data, info)
        
        # generate 30 augmented data for each EEG file
        for i in range(30):
            # randomly select an augmentation technique
            augmentation = random.choice(augmentations)

            # apply the augmentation
            if augmentation == 'scaling':
                scale_factor = random.uniform(0.5, 2.0)
                raw._data *= scale_factor
            elif augmentation == 'translation':
                translation_factor = random.uniform(-50, 50)
                raw._data += translation_factor
            elif augmentation == 'flipping':
                if data.ndim == 2:
                    axis = random.randint(0, 1)
                else:
                    axis = random.randint(0, 2)
                raw._data = np.flip(raw._data, axis)

            # save the augmented data to a new .mat file
            output_file_name = file_name[:-4] + '_' + augmentation + '_' + str(i+1) + '.mat'
            output_file_path = os.path.join(output_folder_path, output_file_name)
            savemat(output_file_path, {'export': raw.get_data()})
# Out:
# Creating RawArray with float64 data, n_channels=7064, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=2567, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6314, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8707, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3230, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=16404, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6228, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=10292, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=2307, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1846, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.

# %% [markdown]
# # Data Augmentation of MCI Data

# %%
import os
import random
import numpy as np
from scipy.io import loadmat, savemat
import mne

# %%
# define the folder path
folder_path = r"D:\Ne\dataset\MCI"

# %%
# define the list of data augmentation techniques
augmentations = ['scaling', 'translation', 'flipping']

# %%
# define the output folder path for the augmented data
output_folder_path = r"D:\Ne\dataset\MCI"

# %%
# create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# %%
# iterate through each .mat file in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith('.mat'):
        # load the EEG data from the .mat file
        mat_data = loadmat(os.path.join(folder_path, file_name))
        data = mat_data['export']
        ch_names = mat_data.get('ch_names', ['chan'+str(i+1) for i in range(data.shape[0])])
        sfreq = mat_data.get('sfreq', 256)  # default sampling frequency is set to 256 Hz
        info = mne.create_info(ch_names=ch_names, sfreq=sfreq, ch_types='eeg')
        raw = mne.io.RawArray(data, info)
        
        # generate 10 augmented data for each EEG file
        for i in range(10):
            # randomly select an augmentation technique
            augmentation = random.choice(augmentations)

            # apply the augmentation
            if augmentation == 'scaling':
                scale_factor = random.uniform(0.5, 2.0)
                raw._data *= scale_factor
            elif augmentation == 'translation':
                translation_factor = random.uniform(-50, 50)
                raw._data += translation_factor
            elif augmentation == 'flipping':
                if data.ndim == 2:
                    axis = random.randint(0, 1)
                else:
                    axis = random.randint(0, 2)
                raw._data = np.flip(raw._data, axis)

            # save the augmented data to a new .mat file
            output_file_name = file_name[:-4] + '_' + augmentation + '_' + str(i+1) + '.mat'
            output_file_path = os.path.join(output_folder_path, output_file_name)
            savemat(output_file_path, {'data': raw.get_data(), 'ch_names': raw.ch_names, 'sfreq': raw.info['sfreq']})
# Out:
# Creating RawArray with float64 data, n_channels=1805, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=9466, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=5514, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=5428, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=12597, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=12659, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=12698, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=12659, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=5834, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=12472, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1977, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=4678, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=12597, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3523, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=12573, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=4241, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=12574, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3242, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=2422, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=12511, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=18415, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=24671, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=4882, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=25069, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=17033, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=18720, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8857, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=16752, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=11364, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3518, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3749, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8707, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3143, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=9591, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3634, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=15136, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1846, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=30415, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=9572, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=16750, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=24044, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=14530, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=5766, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=4412, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3132, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=4498, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=21881, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=13724, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=5681, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=5276, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3085, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=7554, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3226, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3390, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3101, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=12542, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.

# %% [markdown]
# # Data Augmentation of AD Patients

# %%
import os
import random
import numpy as np
from scipy.io import loadmat, savemat
import mne

# %%
# define the folder path
folder_path = r"D:\Ne\dataset\AD_Patients"

# %%
# define the list of data augmentation techniques
augmentations = ['scaling', 'translation', 'flipping']

# %%
# define the output folder path for the augmented data
output_folder_path = r"D:\Ne\dataset\AD_Patients"

# %%
# create the output folder if it doesn't exist
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)

# %%
# iterate through each .mat file in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith('.mat'):
        # load the EEG data from the .mat file
        mat_data = loadmat(os.path.join(folder_path, file_name))
        data = mat_data['export']
        ch_names = mat_data.get('ch_names', ['chan'+str(i+1) for i in range(data.shape[0])])
        sfreq = mat_data.get('sfreq', 256)  # default sampling frequency is set to 256 Hz
        info = mne.create_info(ch_names=ch_names, sfreq=sfreq, ch_types='eeg')
        raw = mne.io.RawArray(data, info)
        
        # generate 10 augmented data for each EEG file
        for i in range(10):
            # randomly select an augmentation technique
            augmentation = random.choice(augmentations)

            # apply the augmentation
            if augmentation == 'scaling':
                scale_factor = random.uniform(0.5, 2.0)
                raw._data *= scale_factor
            elif augmentation == 'translation':
                translation_factor = random.uniform(-50, 50)
                raw._data += translation_factor
            elif augmentation == 'flipping':
                if data.ndim == 2:
                    axis = random.randint(0, 1)
                else:
                    axis = random.randint(0, 2)
                raw._data = np.flip(raw._data, axis)

            # save the augmented data to a new .mat file
            output_file_name = file_name[:-4] + '_' + augmentation + '_' + str(i+1) + '.mat'
            output_file_path = os.path.join(output_folder_path, output_file_name)
            savemat(output_file_path, {'data': raw.get_data(), 'ch_names': raw.ch_names, 'sfreq': raw.info['sfreq']})
# Out:
# Creating RawArray with float64 data, n_channels=7208, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3633, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=38054, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=9716, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=13060, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=17874, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=21882, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=38083, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8707, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=13290, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=38082, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=36728, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3691, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6141, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=37967, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=11014, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=12455, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=4844, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=5940, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=4383, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=24621, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=4325, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=9918, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3000, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3057, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3461, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3691, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=10984, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=4210, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3720, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=30367, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=11561, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1731, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=20786, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3979, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=11618, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=11013, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1010, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1182, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=4267, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=2855, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=4959, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3691, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3547, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=11907, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=5680, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3576, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6891, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1183, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=1789, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=2250, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3576, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=2941, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8765, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=7323, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=10552, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8102, n_times=19
#     Range : 0 ... 18 =      0.000 ...     0.070 secs
# Ready.
